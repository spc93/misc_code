# %%
import sys
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
from dlstools import *
from dlstools.pdnx import *
from matplotlib.pyplot import *
from dlstools.quickfit import *
from dlstools.dirty_fit import fit
from mpl_toolkits.mplot3d import Axes3D 
#%matplotlib inline
# %matplotlib notebook
#pip install lmfit

p='/dls/i16/data/2020/cm26473-1/%i.nxs'

# %%
figure()
for scan in range(820926, 821068):
    n = pdnx(p % scan)

    brl = list(n.bragg)
    idx = np.array(range(len(brl)))
    bstep = (brl[-1] - brl[0])/(len(brl) -1)
    bcalc = brl[0] + idx * bstep
    
    plot(n.en, n.bragg - bcalc, '.')
    #plot(n.bragg - bcalc, '.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /dls_sw/i16/software/python/dlstools/pdnx.py:121: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   setattr(self,'nx',_nx)
# /dls_sw/i16/software/python/dlstools/pdnx.py:121: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   setattr(self,'nx',_nx)
# /dls_sw/i16/software/python/dlstools/pdnx.py:121: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   setattr(self,'nx',_nx)
# /dls_sw/i16/software/python/dlstools/pdnx.py:121: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# ...

# %%
figure()
for scan in range(820926, 821068):
    n = pdnx(p % scan)
    plot(n.en, n.bragg, '.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /dls_sw/i16/software/python/dlstools/pdnx.py:121: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   setattr(self,'nx',_nx)
# /dls_sw/i16/software/python/dlstools/pdnx.py:121: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   setattr(self,'nx',_nx)
# /dls_sw/i16/software/python/dlstools/pdnx.py:121: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   setattr(self,'nx',_nx)
# /dls_sw/i16/software/python/dlstools/pdnx.py:121: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# ...

# %%
#n['en_calc'] = (n['en'].max() -
# Out:
# 5.300000722784901

# %%
brl = list(n.bragg)
idx = np.array(range(len(brl)))
bstep = (brl[-1] - brl[0])/len(brl)
bcalc = brl[0] + idx * bstep

# %%
idx
# Out:
# array([   0,    1,    2, ...,  998,  999, 1000])

# %%
bcalc
# Out:
# array([-21.62908   , -21.62952325, -21.62996649, ..., -22.07144026,
#        -22.07188351, -22.07232675])

# %%
list(n.bragg)
# Out:
# [-21.62908,
#  -21.629525,
#  -21.62995,
#  -21.630395,
#  -21.63082,
#  -21.63126,
#  -21.63168,
#  -21.632125,
#  -21.63256,
#  -21.633,
#  -21.63343,
#  -21.63387,
#  -21.6343,
#  -21.63472,
#  -21.635165,
#  -21.635605,
#  -21.636035,
#  -21.636465,
#  -21.63691,
#  -21.637345,
#  -21.637785,
#  -21.63822,
#  -21.638655,
#  -21.639085,
#  -21.639515,
#  -21.63995,
#  -21.64039,
#  -21.64082,
#  -21.64126,
#  -21.64169,
#  -21.64213,
#  -21.64257,
#  -21.643005,
#  -21.64344,
#  -21.643865,
#  -21.644315,
#  -21.64474,
#  -21.645175,
#  -21.64561,
#  -21.646035,
#  -21.646485,
#  -21.646905,
#  -21.64736,
#  -21.64779,
#  -21.64822,
#  -21.64866,
#  -21.649095,
#  -21.64953,
#  -21.64997,
#  -21.650395,
#  -21.65083,
#  -21.65127,
#  -21.65169,
#  -21.652145,
#  -21.65258,
#  -21.653015,
#  -21.65345,
#  -21.653895,
#  -21.654315,
#  -21.654755,
#  -21.6552,
#  -21.655625,
#  -21.656065,
#  -21.6565,
#  -21.656935,
#  -21.657365,
#  -21.65781,
#  -21.65824,
#  -21.658685,
# ...
